# %% [markdown]
# ## Importing the necessary library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from scipy.stats import zscore
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, power_transform, LabelEncoder

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv(r'C:\Users\LENOVO\Documents\Post Graduation\data sets\Data-Science-ML-Capstone-Projects-master\Data-Science-ML-Capstone-Projects-master\baseball.csv')
dataset.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %% [markdown]
# ### The data has 30 rows and 17 columns

# %%
dataset.shape
# Out:
# (30, 17)

# %%
dataset.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# ### Upon review I see that all the columns standard deviation is valid when compared to its mean

# %%
sns.scatterplot(x = 'R',y='W',data = dataset)

# %% [markdown]
# ### There is minor positive relationship for the R and number of wins (W)

# %%
sns.scatterplot(x = 'AB',y='W',data = dataset)

# %% [markdown]
# ### There is no relationship for the AB and number of wins (W)

# %%
sns.scatterplot(x = 'H',y='W',data = dataset)

# %% [markdown]
# ### There is no relationship for the H and number of wins (W)

# %%
sns.scatterplot(x = '2B',y='W',data = dataset)

# %% [markdown]
# ### There is a minor positive relationship for the 2B and number of wins (W)

# %%
sns.scatterplot(x = '3B',y='W',data = dataset)

# %% [markdown]
# ### There is no relationship for the 3B and number of wins (W)

# %%
sns.scatterplot(x = 'HR',y='W',data = dataset)

# %% [markdown]
# ### There is a minor positive relationship for the HR and number of wins (W)

# %%
sns.scatterplot(x = 'BB',y='W',data = dataset)

# %% [markdown]
# ### There is a minor positive relationship for the BB and number of wins (W)

# %%
sns.scatterplot(x = 'SO',y='W',data = dataset)

# %% [markdown]
# ### There is no relationship for the SO and number of wins (W)

# %%
sns.scatterplot(x = 'SB',y='W',data = dataset)

# %% [markdown]
# ### There is no relationship for the SB and number of wins (W)

# %%
sns.scatterplot(x = 'RA',y='W',data = dataset)

# %% [markdown]
# ### There is a good strong relationship for the RA and number of wins (W)

# %%
sns.scatterplot(x = 'ER',y='W',data = dataset)

# %% [markdown]
# ### There is a good negative relationship for the RA and number of wins (W)

# %%
sns.scatterplot(x = 'ERA',y='W',data = dataset)

# %% [markdown]
# ### There is a good negative relationship for the ERA and number of wins (W)

# %%
sns.scatterplot(x = 'CG',y='W',data = dataset)

# %% [markdown]
# ### There is no relationship for the CG and number of wins (W)

# %%
sns.scatterplot(x = 'SHO',y='W',data = dataset)

# %% [markdown]
# ### There is no relationship for the SHO and number of wins (W)

# %%
sns.scatterplot(x = 'SV',y='W',data = dataset)

# %% [markdown]
# ### There is a positive relationship for the SV and number of wins (W)

# %%
sns.scatterplot(x = 'E',y='W',data = dataset)

# %% [markdown]
# ### There is no relationship for the RA and number of wins (W)

# %% [markdown]
# ## Checking for data distribution for the variables, to view whether it is normal or not

# %%
plt.figure(figsize = (20,35))
pltnum = 1
for i in dataset:
    if pltnum <=18:
        plt.subplot(6,3,pltnum)
        sns.distplot(dataset[i], color = 'lightgreen')
        plt.xlabel(i,fontsize = 20)
    pltnum+=1
plt.show()

# %% [markdown]
# ### Looking for correlation coefficient for the independent variables with the dependent one

# %%
corr_data = dataset.corr()
corr_data['W'].sort_values(ascending = False)
# Out:
# W      1.000000
# SV     0.666530
# BB     0.484342
# SHO    0.471805
# R      0.430751
# 2B     0.427797
# HR     0.307407
# SO     0.111850
# CG     0.080533
# H      0.037612
# AB    -0.087947
# E     -0.089485
# SB    -0.157234
# 3B    -0.251118
# ER    -0.809435
# RA    -0.812952
# ERA   -0.819600
# Name: W, dtype: float64

# %% [markdown]
# ## Column SV has hoghest positive correlation and column ERA has highest negative correlation

# %% [markdown]
# ## Checking for multi-collenearity

# %%
plt.figure(figsize = (20,15))
sns.heatmap(corr_data,annot = True)

# %% [markdown]
# ### Upon review, i see that the columns RA,ER and ERA has highest correlation

# %% [markdown]
# ## Checking for outliers

# %%
plt.figure(figsize = (30,70))
pltnum = 1
for i in dataset:
    if pltnum <=180:
        plt.subplot(6,30,pltnum)
        sns.boxplot(dataset[i], color = 'lightgreen', orient = 'v')
        plt.xlabel(i,fontsize = 15)
    pltnum+=1
plt.show()

# %% [markdown]
# ## Column E has hoghest number of outliers and rest are negligible

# %%
z = np.abs(zscore(dataset[['E']]))
z
# Out:
# array([[0.46146963],
#        [0.60719689],
#        [1.11724227],
#        [0.48575751],
#        [0.60719689],
#        [0.46146963],
#        [0.0971515 ],
#        [1.26296953],
#        [0.04857575],
#        [0.194303  ],
#        [1.79730279],
#        [0.68006051],
#        [0.0971515 ],
#        [0.02428788],
#        [2.30734817],
#        [0.12143938],
#        [2.01589367],
#        [1.21439378],
#        [1.57871191],
#        [0.31574238],
#        [0.46146963],
#        [0.31574238],
#        [1.26296953],
#        [0.31574238],
#        [1.65157553],
#        [1.40869678],
#        [1.1901059 ],
#        [0.60719689],
#        [0.17001513],
#        [0.04857575]])

# %% [markdown]
# ### Checking the Z-score and removing the outlier using zscore method

# %%
ds_new = dataset[(z<2).all(axis = 1)]
print(dataset.shape)
print(ds_new.shape)
# Out:
# (30, 17)
# (28, 17)

# %% [markdown]
# ## There is approximately 7-8% data loss

# %% [markdown]
# ## Checking for Skewness

# %%
ds_new.skew()
# Out:
# W     -0.004958
# R      1.194037
# AB     0.294350
# H      0.766815
# 2B    -0.145911
# 3B     0.147206
# HR     0.400626
# BB     0.149733
# SO    -0.167915
# SB     0.512281
# RA     0.043121
# ER     0.068979
# ERA    0.098834
# CG     0.781977
# SHO    0.698213
# SV     1.029483
# E      0.893043
# dtype: float64

# %% [markdown]
# ### Feature R, H, SB, CG, SHO, SV and E has skewness

# %% [markdown]
# ## Splitting data into x and y

# %%
x = ds_new.drop(columns = 'W')
y = ds_new['W']

# %% [markdown]
# ## Applying cbrt transformation as the power transformer makes some variables to 0 and I'm not achieving good score

# %%
tr_data = np.cbrt(x)
x = pd.DataFrame(tr_data, columns = x.columns)

# %%
x.skew()
# Out:
# R      0.902246
# AB     0.277338
# H      0.740474
# 2B    -0.242048
# 3B    -0.226837
# HR     0.056582
# BB     0.022089
# SO    -0.445698
# SB     0.097321
# RA    -0.158971
# ER    -0.170051
# ERA   -0.166560
# CG    -1.016332
# SHO   -0.161847
# SV     0.772167
# E      0.695383
# dtype: float64

# %%
scale = StandardScaler()
scaled = scale.fit_transform(x)

# %% [markdown]
# ### Skewness has reduced to some extent, But I Still see some skewness and I'm proceeding with it because, i will be able to use regularization techniques to fix the issue

# %%
plt.figure(figsize = (20,35))
pltnum = 1
for i in x:
    if pltnum <=18:
        plt.subplot(6,3,pltnum)
        sns.distplot(x[i], color = 'red')
        plt.xlabel(i,fontsize = 20)
    pltnum+=1
plt.show()

# %% [markdown]
# ## The score is not improving hence removing the multi-collenear columns

# %%
x = x.drop(columns = ['ERA'])

# %% [markdown]
# ## Checking fo multicollinearity post removal of the variable

# %%
cor  = x.corr()
plt.figure(figsize= (20,15))
sns.heatmap(cor,annot = True)

# %% [markdown]
# ## there are only few outliers for the data and the features are almost following normal distribution

# %%
plt.figure(figsize = (30,70))
pltnum = 1
for i in x:
    if pltnum <=180:
        plt.subplot(6,30,pltnum)
        sns.boxplot(x[i], color = 'lightgreen', orient = 'v')
        plt.xlabel(i,fontsize = 15)
    pltnum+=1
plt.show()

# %% [markdown]
# ### Finding the best randomstate based on the r2 score

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
for i in range(0,3000):
    x_train,x_test,y_train,y_test =  train_test_split(x,y,random_state = i)
    linr = LinearRegression()
    linr.fit(x_train,y_train)
    trn_pred = linr.predict(x_train)
    tst_pred = linr.predict(x_test)
    trn_score = linr.score(x_train,y_train)
    tst_score = linr.score(x_test,y_test)
    if round(trn_score,1)== round(tst_score,1):
        brs = i
print('The best random state is', i)
# Out:
# The best random state is 2999

# %% [markdown]
# ## Model 1 Linear Regression

# %%
x_train,x_test, y_train,y_test = train_test_split(x,y, random_state = 2999)
lin = LinearRegression()
lin.fit(x_train,y_train)
lin_pred = lin.predict(x_test)
lin_score = lin.score(x_test,y_test)
lin_score
# Out:
# 0.42858717366550836

# %%
lin_rmse = np.sqrt(mean_squared_error(y_test,lin_pred))
print('RMSE for Linear Regression: ', lin_rmse)
# Out:
# RMSE for Linear Regression:  7.2215072192521665

# %% [markdown]
# ## Model 2 Decision Tree Regression

# %%
from sklearn.ensemble import RandomForestRegressor
rfr =  RandomForestRegressor()
rfr.fit(x_train,y_train)
rfr_pred = rfr.predict(x_test)
rfr_score = rfr.score(x_test,y_test)
rfr_score
# Out:
# 0.6254701028622542

# %%
rfr_rmse = np.sqrt(mean_squared_error(y_test,rfr_pred))
print('RMSE for Random Forest Regression: ', rfr_rmse)
# Out:
# RMSE for Random Forest Regression:  5.846502006694746

# %% [markdown]
# ## Model 3 Ada Boost Regression

# %%
from sklearn.ensemble import AdaBoostRegressor
ada = AdaBoostRegressor()
ada.fit(x_train,y_train)
ada_pred = ada.predict(x_test)
ada_score = ada.score(x_test,y_test)
ada_score
# Out:
# 0.5580541269131384

# %%
ada_rmse = np.sqrt(mean_squared_error(y_test,ada_pred))
print('RMSE for AdaBoost Regression: ', ada_rmse)
# Out:
# RMSE for AdaBoost Regression:  6.350931065349821

# %% [markdown]
# ## Model 4 Extra Trees Regression

# %%
from sklearn.ensemble import ExtraTreesRegressor
et = ExtraTreesRegressor()
et.fit(x_train,y_train)
et_pred = et.predict(x_test)
et_score = et.score(x_test,y_test)
et_score
# Out:
# 0.6438897137745976

# %%
et_rmse = np.sqrt(mean_squared_error(y_test,et_pred))
print('RMSE for Extra trees Regression: ', et_rmse)
# Out:
# RMSE for Extra trees Regression:  5.700922231158243

# %% [markdown]
# ## Model 5 Ridge Regression (Regularisation technique)

# %%
from sklearn.linear_model import Ridge, RidgeCV
ridgecv = RidgeCV(alphas = np.arange(0.001,0.1,0.01), normalize = True)
ridgecv.fit(x_train, y_train)
# Out:
# RidgeCV(alphas=array([0.001, 0.011, 0.021, 0.031, 0.041, 0.051, 0.061, 0.071, 0.081,
#        0.091]),
#         normalize=True)

# %%
alpha = ridgecv.alpha_
ridge = Ridge(alpha)
ridge.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.09099999999999998)

# %%
rid_pred = ridge.predict(x_test)
rid_score = ridge.score(x_test,y_test)
rid_score
# Out:
# 0.8261289809348918

# %%
rid_rmse = np.sqrt(mean_squared_error(y_test,rid_pred))
print('RMSE for Ridge Regression: ', rid_rmse)
# Out:
# RMSE for Ridge Regression:  3.9835150032100115

# %% [markdown]
# ### Using cross_val_score to get the cross validatoin score for each model

# %%
from sklearn.model_selection import cross_val_score
cv = cross_val_score(lin,x,y,scoring ='r2',cv=7)
cv = cv.mean()
cv
# Out:
# 0.5519045566261002

# %%
cv1 = cross_val_score(rfr,x,y,scoring ='r2',cv=7)
cv1 = cv1.mean()
cv1
# Out:
# -0.3327575178593211

# %%
cv2 = cross_val_score(ada,x,y,scoring ='r2',cv=7)
cv2 = cv2.mean()
cv2
# Out:
# -0.36336197857218205

# %%
cv3 = cross_val_score(et,x,y,scoring ='r2',cv=7)
cv3 = cv3.mean()
cv3
# Out:
# -0.3760466328508816

# %%
cv4 = cross_val_score(ridge,x,y,scoring ='r2',cv=7)
cv4 = cv4.mean()
cv4
# Out:
# 0.6390770393580294

# %% [markdown]
# ## Finding the best model

# %%
mod = [lin_score,rfr_score,ada_score,et_score,rid_score]
cv =  [cv,cv1,cv2,cv3,cv4]
model = pd.DataFrame({})
model['mod'] = mod
model['cv'] = cv
model['Diff'] = model['mod'] - model['cv']
model
# Out:
#         mod        cv      Diff
# 0  0.428587  0.551905 -0.123317
# 1  0.625470 -0.332758  0.958228
# 2  0.558054 -0.363362  0.921416
# 3  0.643890 -0.376047  1.019936
# 4  0.826129  0.639077  0.187052

# %% [markdown]
# ## Selecting ridge as best model, because the Linear regression has poor score and it cannot be used for hyper paramter tuning too. However, ridge is same as linear regression with regularization and can be used for hyper parameter tuning

# %% [markdown]
# ## Hyper Parameter Tuning on Ridge Regression

# %%
params = {'alpha':np.arange(0.001,1,0.001),
         'normalize':[True,False],
         'max_iter':[200,400,600,800,1000],
         'fit_intercept':[True,False]}

# %%
gcv = GridSearchCV(Ridge(),params,cv=7)
gcv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=7, estimator=Ridge(),
#              param_grid={'alpha': array([0.001, 0.002, 0.003, 0.004, 0.005, 0.006, 0.007, 0.008, 0.009,
#        0.01 , 0.011, 0.012, 0.013, 0.014, 0.015, 0.016, 0.017, 0.018,
#        0.019, 0.02 , 0.021, 0.022, 0.023, 0.024, 0.025, 0.026, 0.027,
#        0.028, 0.029, 0.03 , 0.031, 0.032, 0.033, 0.034, 0.035, 0.036,
#        0.037, 0.038, 0.039, 0.04 , 0.041, 0.042, 0.043, 0.044, 0.045,
#        0.046, 0.047, 0.048, 0.0...
#        0.955, 0.956, 0.957, 0.958, 0.959, 0.96 , 0.961, 0.962, 0.963,
#        0.964, 0.965, 0.966, 0.967, 0.968, 0.969, 0.97 , 0.971, 0.972,
#        0.973, 0.974, 0.975, 0.976, 0.977, 0.978, 0.979, 0.98 , 0.981,
#        0.982, 0.983, 0.984, 0.985, 0.986, 0.987, 0.988, 0.989, 0.99 ,
#        0.991, 0.992, 0.993, 0.994, 0.995, 0.996, 0.997, 0.998, 0.999]),
#                          'fit_intercept': [True, False],
#                          'max_iter': [200, 400, 600, 800, 1000],
# ...

# %%
gcv.best_params_
# Out:
# {'alpha': 0.999, 'fit_intercept': False, 'max_iter': 200, 'normalize': True}

# %%
rid = Ridge(alpha = 0.9991, fit_intercept = False, max_iter =200, normalize = True)
rid.fit(x_train,y_train)
fin_score = rid.score(x_test,y_test)
fin_pred = rid.predict(x_test)
print(fin_score)
# Out:
# 0.7076992035797752

# %%
fin_rmse = np.sqrt(mean_squared_error(y_test,fin_pred))
print('RMSE for Ridge Regression: ', fin_rmse)
# Out:
# RMSE for Ridge Regression:  5.164970635456455

# %% [markdown]
# ## Saving the previous ridge model because it provided better RMSE and R2 score

# %%
import joblib
joblib.dump(ridge,'baseball.pkl')
# Out:
# ['baseball.pkl']
